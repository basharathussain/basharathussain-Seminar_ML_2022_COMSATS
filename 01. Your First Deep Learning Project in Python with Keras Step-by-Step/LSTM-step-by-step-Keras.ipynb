# %% [markdown]
# <a href="https://colab.research.google.com/drive/1CiVkP7Xz_g4aFdOdZcOxDg6r-h9vKSjd"
#  target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Prepared by Basharat Hussain on 20/8/2022
# This tutorial is modified version from machinelearningmastery.com

# %% [markdown]
# The **steps** you will learn in this tutorial are as follows:
#
# 1.   Load Data
# 2.   Define Keras Model
# 3.   Compile Keras Model
# 4.   Fit Keras Model
# 5.   Evaluate Keras Model
# 6.   Make Predictions

# %% [markdown]
# **Prepration Steps -- access Google Drive and Mount Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')

dataset_path = "/content/drive/My Drive/Google-CoLab/Seminar_ML_2022_CAMSATS/01. Your First Deep Learning Project in Python with Keras Step-by-Step/pima-indians-diabetes.data.csv"
dataset_path
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/Google-CoLab/Seminar_ML_2022_CAMSATS/01. Your First Deep Learning Project in Python with Keras Step-by-Step/pima-indians-diabetes.data.csv'

# %% [markdown]
# **1. Load Data**
#
#
# pima-indians-diabetes.csv
#
# **Input Variables (X):**
#
# 1. Pregnant - number of times
# 2. Plasma glucose concentration at 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 7. Age (years)
#
#
# **Output Variables (y):**
#
# 1. Class variable (0 or 1)
#
# **Data Header**
#
# 6,148,72,35,0,33.6,0.627,50,1
#
# 1,85,66,29,0,26.6,0.351,31,0
#
# 8,183,64,0,0,23.3,0.672,32,1
#
# 1,89,66,23,94,28.1,0.167,21,0
#
# 0,137,40,35,168,43.1,2.288,33,1

# %%
# first neural network with keras tutorial
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# Use dataset_path to load the data from csv file

# %%
# load the dataset
dataset = loadtxt(dataset_path, delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]

# %%
print(X.shape)
print (y.shape)
print(X)
# Out:
# (768, 8)
# (768,)
# [[  6.    148.     72.    ...  33.6     0.627  50.   ]
#  [  1.     85.     66.    ...  26.6     0.351  31.   ]
#  [  8.    183.     64.    ...  23.3     0.672  32.   ]
#  ...
#  [  5.    121.     72.    ...  26.2     0.245  30.   ]
#  [  1.    126.     60.    ...  30.1     0.349  47.   ]
#  [  1.     93.     70.    ...  30.4     0.315  23.   ]]

# %% [markdown]
# **2. Define Keras Model**
#
# create a Sequential model and add layers one at a time

# %%
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# **3. Compile Keras Model**

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# you can print summary of the compiled Model

# %%
# Print a summary of the Keras model:
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 12)                108
#
#  dense_7 (Dense)             (None, 8)                 104
#
#  dense_8 (Dense)             (None, 1)                 9
#
# ...
# Total params: 221
# Trainable params: 221
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **4. Fit Keras Model**
#
# Training occurs over epochs, and each epoch is split into batches.
#
# **Epoch**: One pass through all of the rows in the training dataset
#
# **Batch**: One or more samples considered by the model within an epoch before weights are updated

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)

# %% [markdown]
# **5. Evaluate Keras Model**

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))

# %% [markdown]
# Hide the output progress bars during training. You can off by setting verbose=0

# %%
# fit the keras model on the dataset without progress bars
model.fit(X, y, epochs=150, batch_size=10, verbose=0)
# evaluate the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 65.49

# %% [markdown]
# **6. Make Predictions**
#
# “After I train my model, how can I use it to make predictions on new data?”

# %%
from termcolor import colored
print(colored("hello red world **BOLD TEXT**", 'red'))
# Out:
# hello red world **BOLD TEXT**

# %%
# make probability predictions with the model
predictions = model.predict(X)
# round predictions 
predictions = (predictions > 0.5).astype(int)

# summarize the first 5 cases
for i in range(20):
	print('%s => %d (expected %d) %s' % (X[i].tolist(), predictions[i], y[i], colored("**FALSE PREDICTION**", 'red') if predictions[i] != y[i] else ""))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)
# [5.0, 116.0, 74.0, 0.0, 0.0, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1) **FALSE PREDICTION**
# [10.0, 115.0, 0.0, 0.0, 0.0, 35.3, 0.134, 29.0] => 0 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 1 (expected 1)
# [8.0, 125.0, 96.0, 0.0, 0.0, 0.0, 0.232, 54.0] => 1 (expected 1)
# [4.0, 110.0, 92.0, 0.0, 0.0, 37.6, 0.191, 30.0] => 0 (expected 0)
# [10.0, 168.0, 74.0, 0.0, 0.0, 38.0, 0.537, 34.0] => 1 (expected 1)
# [10.0, 139.0, 80.0, 0.0, 0.0, 27.1, 1.441, 57.0] => 0 (expected 0)
# [1.0, 189.0, 60.0, 23.0, 846.0, 30.1, 0.398, 59.0] => 1 (expected 1)
# ...

# %% [markdown]
# **a deep MLP with five hidden layers**

# %%
# define the model
model = Sequential()
model.add(Dense(100, input_shape=(8,)))
model.add(Dense(80))
model.add(Dense(30))
model.add(Dense(10))
model.add(Dense(5))
model.add(Dense(1))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit model
model.fit(X, y, epochs=200, batch_size=10, verbose=2)
 
# evaluate the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))

# demonstrate prediction
predictions = model.predict(X)
# round predictions 
predictions = (predictions > 0.5).astype(int)

# summarize the first 5 cases
for i in range(20):
	print('%s => %d (expected %d) %s' % (X[i].tolist(), predictions[i], y[i], colored("**FALSE PREDICTION**", 'red') if predictions[i] != y[i] else ""))
# Out:
# Epoch 1/200
# 77/77 - 1s - loss: 5.4021 - accuracy: 0.6497 - 1s/epoch - 13ms/step
# Epoch 2/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 165ms/epoch - 2ms/step
# Epoch 3/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 164ms/epoch - 2ms/step
# Epoch 4/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 148ms/epoch - 2ms/step
# Epoch 5/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 149ms/epoch - 2ms/step
# Epoch 6/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 158ms/epoch - 2ms/step
# Epoch 7/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 149ms/epoch - 2ms/step
# Epoch 8/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 155ms/epoch - 2ms/step
# Epoch 9/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 153ms/epoch - 2ms/step
# Epoch 10/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 153ms/epoch - 2ms/step
# Epoch 11/200
# 77/77 - 0s - loss: 5.4021 - accuracy: 0.6497 - 159ms/epoch - 2ms/step
# Epoch 12/200
# ...
